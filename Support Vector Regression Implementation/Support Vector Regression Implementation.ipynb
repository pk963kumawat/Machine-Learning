# %%
## Dataset (Tips Dataset)
import seaborn as sns
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df=sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
## Feature Encoding (Label Encoding and One-Hot Encoding)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
## Independent and Dependent Features
x=df[['tip','size','sex','smoker','day','time']]
y=df['total_bill']

# %%
## Train and Test Split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.head()
# Out:
#       tip  size   sex smoker   day    time
# 228  2.72     2  Male     No   Sat  Dinner
# 208  2.03     2  Male    Yes   Sat  Dinner
# 96   4.00     2  Male    Yes   Fri  Dinner
# 167  4.50     4  Male     No   Sun  Dinner
# 84   2.03     2  Male     No  Thur   Lunch

# %%
## Feature Encoding (Label Encoding and One-Hot Encoding)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
le1= LabelEncoder()
le2= LabelEncoder()
le3= LabelEncoder()

# %%
x_train['sex'] = le1.fit_transform(x_train['sex'])
x_train['smoker'] = le2.fit_transform(x_train['smoker'])
x_train['time'] = le3.fit_transform(x_train['time'])

# %%
x_train.head()
# Out:
#       tip  size  sex  smoker   day  time
# 228  2.72     2    1       0   Sat     0
# 208  2.03     2    1       1   Sat     0
# 96   4.00     2    1       1   Fri     0
# 167  4.50     4    1       0   Sun     0
# 84   2.03     2    1       0  Thur     1

# %%
x_test['sex'] = le1.transform(x_test['sex'])
x_test['smoker'] = le2.transform(x_test['smoker'])
x_test['time'] = le3.transform(x_test['time'])

# %%
x_test.head()
# Out:
#       tip  size  sex  smoker   day  time
# 24   3.18     2    1       0   Sat     0
# 6    2.00     2    1       0   Sun     0
# 153  2.00     4    1       0   Sun     0
# 211  5.16     4    1       1   Sat     0
# 198  2.00     2    0       1  Thur     1

# %%
## Onehot encoding--- ColumnTransformer

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ct = ColumnTransformer(transformers=[('onehot',OneHotEncoder(drop='first'),[3])],remainder='passthrough')

# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)
x_train=ct.fit_transform(x_train)

# %%
x_test=ct.transform(x_test)

# %%
x_test
# Out:
# array([[0.0, 3.18, 2, 1, 'Sat', 0],
#        [0.0, 2.0, 2, 1, 'Sun', 0],
#        [0.0, 2.0, 4, 1, 'Sun', 0],
#        [1.0, 5.16, 4, 1, 'Sat', 0],
#        [1.0, 2.0, 2, 0, 'Thur', 1],
#        [1.0, 2.0, 2, 1, 'Sun', 0],
#        [1.0, 2.56, 2, 1, 'Thur', 1],
#        [0.0, 2.52, 2, 0, 'Thur', 1],
#        [0.0, 3.23, 2, 1, 'Sun', 0],
#        [1.0, 3.0, 2, 0, 'Fri', 0],
#        [0.0, 3.0, 2, 1, 'Sun', 0],
#        [0.0, 1.47, 2, 1, 'Sat', 0],
#        [0.0, 1.5, 2, 0, 'Thur', 1],
#        [1.0, 2.0, 2, 1, 'Sun', 0],
#        [0.0, 1.83, 1, 0, 'Thur', 1],
#        [0.0, 1.36, 3, 0, 'Thur', 1],
#        [1.0, 4.0, 3, 1, 'Thur', 1],
#        [0.0, 3.92, 2, 1, 'Sun', 0],
#        [0.0, 2.47, 2, 0, 'Sat', 0],
#        [0.0, 5.0, 5, 1, 'Thur', 1],
#        [0.0, 2.45, 4, 0, 'Sat', 0],
#        [0.0, 3.35, 3, 1, 'Sat', 0],
#        [1.0, 4.0, 2, 0, 'Sat', 0],
#        [0.0, 1.45, 2, 1, 'Sat', 0],
#        [1.0, 3.5, 3, 0, 'Sun', 0],
#        [0.0, 2.31, 2, 1, 'Thur', 1],
#        [0.0, 1.71, 2, 1, 'Sun', 0],
#        [1.0, 5.0, 2, 0, 'Sat', 0],
#        [0.0, 2.0, 4, 1, 'Sun', 0],
#        [0.0, 5.0, 6, 1, 'Sun', 0],
#        [0.0, 4.0, 3, 1, 'Sun', 0],
#        [1.0, 1.44, 2, 1, 'Sat', 0],
#        [0.0, 2.34, 4, 1, 'Sat', 0],
#        [1.0, 3.21, 2, 1, 'Sat', 0],
#        [0.0, 3.5, 3, 0, 'Sun', 0],
#        [0.0, 2.92, 4, 0, 'Thur', 1],
#        [1.0, 1.5, 2, 1, 'Fri', 0],
#        [1.0, 5.0, 4, 0, 'Thur', 1],
#        [0.0, 2.75, 2, 0, 'Thur', 1],
#        [1.0, 2.0, 2, 1, 'Sat', 0],
#        [0.0, 1.25, 2, 1, 'Sat', 0],
#        [0.0, 2.0, 2, 0, 'Thur', 1],
#        [0.0, 2.55, 2, 1, 'Sun', 0],
#        [0.0, 1.67, 3, 0, 'Sun', 0],
#        [1.0, 2.0, 2, 1, 'Thur', 1],
#        [1.0, 1.0, 1, 0, 'Sat', 0],
#        [1.0, 1.61, 2, 0, 'Sat', 0],
#        [0.0, 2.31, 3, 1, 'Sat', 0],
#        [0.0, 1.44, 2, 1, 'Thur', 1]], dtype=object)

# %%
## SVR -- Support Vector Regression
from sklearn.svm import SVR
svr = SVR()

# %%
svr.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_pred = svr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R^2 Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 58.73862766650745
# R^2 Score: 0.30723391466592354
